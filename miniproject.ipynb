# %%
import tweepy
from textblob import TextBlob
import matplotlib.pyplot as plt

# %%
#all authentication keys to access twitter API
# to connect as or to jump to server/ reverse the proxy server
consumer_key = "8AO6OU5ubyi4XO47b1C7Sjdlz"
consumer_sec = "FS1usPrfPolvjLXbwGka5N8TWkOZhUsdxGmmTwuO016koesUSt"

# from proxy server in order to connect to server
access_token = "1151573806680592384-OUFeUtpsRFZM6jQxl1AG99NEjlY0Kt"
access_token_sec = "KKHmkHkDGVaDof8XK4fKKI52DmNl4vZlaXnx85WRfd4Lr"

# %%
# connected to jump server of twitter
auth = tweepy.OAuthHandler(consumer_key,consumer_sec)

# %%
# now we can connect from jump server to web server of twitter
auth.set_access_token(access_token,access_token_sec)

# %%
#now we can connect to API strong server of twitter
api_connect=tweepy.API(auth)

# %%
tweet_data = api_connect.search('India',count=100)

# %%
tweet_data

# %%
for tweet in tweet_data:
  print(tweet.text)
# Out:
# @Rafoobhai39 @Uz_Khawaja virat kha
# @_AkashStyles_ @Haneesh_virat Real life la na Rohit fan nu yarayu perusa pakala .
# Some boys sachin fans avana support panuvanga
# @shyamsteel C. Chole Bhature
#
# #Virushka #Virat #Anushka #Contest #TVCContest #ContestAlert #ShyamSteel #TMTBars… https://t.co/YRVWdBN1uk
# RT @peak_Ability18: DYK? Sir Vivian Richards gifted Virat Kohli this book.🧐 https://t.co/AjZI0XGR0V
# RT @MsHaidri: After Virat kohli Debut India Has Chase Down 300+ 9 Time
# And 7 Of Them Virat kohli Has Scored Century💯
#
# Chase Monster 👑🐐 @i…
# RT @ViratGang: How Many Retweets For Virat Kohli In Glasses? 🤓❤
#
# @imVkohli • #ViratKohli • #ViratGang https://t.co/tSKbS09VwN
# One8 Willow Deodorant, 200 ml with Willow Deodorant
#
# Only for Rs. 194/- + Discounts||Cashbacks
#
# Link:… https://t.co/w4TBQWF8Ei
# @imkuldeep18 Waiting for your comeback 🙌🏻
# @Kartikgodara333 Virat crying in corner 😭
# RT @peak_Ability18: DYK? Sir Vivian Richards gifted Virat Kohli this book.🧐 https://t.co/AjZI0XGR0V
# RT @CricCrazyJohns: India ends as number 1 Test side in the annual ranking for the 5th consecutive year: 2017,2018,2019,2020,2021 - The dom…
# @raaghul_07 Kane and Virat
# @Rakesh_254 @RaviBhai2705 Better average than Virat in tests in Eng &amp; NZ
# RT @shyamsteel: In this video, Anushka orders Virat’s favorite dish. What is Virat Kohli’s all-time favorite dish? Watch the video &amp; tell u…
# RT @Nitin__10: Virat Kohli is the Best ever Captain in Test Cricket. Period.
# RT @Cricketracker: Average of Indian batsmen in Tests since 2020:
#
# Rohit Sharma - 47.40
# Rishabh Pant - 46.46
# Shubman Gill - 34.36
# Cheteshw…
# RT @CricCrazyJohns: India ends as number 1 Test side in the annual ranking for the 5th consecutive year: 2017,2018,2019,2020,2021 - The dom…
India ends as number 1 Test side in the annual ranking for the 5th consecutive year: 2017,2018,2019,2020,2021 - The dominat…
# RT @Cricketracker: Average of Indian batsmen in Tests since 2020:
#
# Rohit Sharma - 47.40
# Rishabh Pant - 46.46
# Shubman Gill - 34.36
# Cheteshw…
# @Virat_Mamta @Ammar_Returns Ache pado tweet
# RT @KishoreJSP_VK: India ends as number 1 Test side in the annual ranking for the 5th consecutive year: 2017,2018,2019,2020,2021 - The domi…
# RT @AkashKu97829120: 3-4 months before India register historical win against Australia in Australia,and win @Gabba where Australia were und…
# RT @Thala_Virat18: Virat Kohli Holding His Haters... https://t.co/VUibjKVamr
# India ends as number 1 Test side in the annual ranking for the 5th consecutive year: 2017,2018,2019,2020,2021 - The… https://t.co/3zjJrEO876
# RT @CricCrazyJohns: India ends as number 1 Test side in the annual ranking for the 5th consecutive year: 2017,2018,2019,2020,2021 - The dom…
# @ComeonPant Virat Kohli's cover drive
# RT @peak_Ability18: DYK? Sir Vivian Richards gifted Virat Kohli this book.🧐 https://t.co/AjZI0XGR0V
# RT @CricCrazyJohns: India ends as number 1 Test side in the annual ranking for the 5th consecutive year: 2017,2018,2019,2020,2021 - The dom…
# RT @CricCrazyJohns: India ends as number 1 Test side in the annual ranking for the 5th consecutive year: 2017,2018,2019,2020,2021 - The dom…
# @CricCrazyJohns Get well soon 🙏🏻
# #TeamIndia
# #virat
# #kohli
# #icc
# #viratkohli https://t.co/nDbI5Sgc64
# @tellychakkar @StarPlus Sai kuch batati to h nahi virat ko.. Phir bechara ko hi log Koste h... sai ko pehle virat k… https://t.co/2qssrECVe0
# RT @KishoreJSP_VK: India ends as number 1 Test side in the annual ranking for the 5th consecutive year: 2017,2018,2019,2020,2021 - The domi…
# RT @IBeingPratik1: London me bartan manjne ka kaam krti ho kya behen. @Virat_Mamta ? https://t.co/RIN4INDkAp
# RT @favs_lover: Virat Rocked Everyone Shocked😎👏🔥
#
# Just Love the Way How Amazingly Virat Defend His Sai in front of whole family when they w…
# RT @bhawnakohli5: The legacy of Virat Kohli as captain is developing the culture of fast bowling in longer format, fitness and continuing a…
# RT @Cricketracker: Average of Indian batsmen in Tests since 2020:
#
# Rohit Sharma - 47.40
# Rishabh Pant - 46.46
# Shubman Gill - 34.36
# Cheteshw…
# RT @im_viratian_1: Virat Kohli is a selfless cricketer who enjoys seeing his teammates happy 😍
#
# @imVkohli The most Selfless Crickter In my…
# RT @ViratFanTeam: Team India ends as "No.1 TEST SIDE" in the annual ranking for the 5th consecutive year.
#
#  2017,2018,2019,2020,2021
#
# The…
# RT @CricCrazyJohns: India ends as number 1 Test side in the annual ranking for the 5th consecutive year: 2017,2018,2019,2020,2021 - The dom…
# RT @CricCrazyJohns: India ends as number 1 Test side in the annual ranking for the 5th consecutive year: 2017,2018,2019,2020,2021 - The dom…
# RT @ComeonPant: Team India No.1 Test Team in The World:-
#
# •2017 - No.1
# •2018 - No.1
# •2019 - No.1
# •2020 - No.1
# •2021 - No.1*
#
# That's some do…
# RT @shyamsteel: In these difficult times, Virat Kohli &amp; Anushka Sharma have come together to raise funds for people who need urgent medical…
# Virat is the BEST ever Test Captain.
# Argue with the wall.
# @Virat_Mamta @_Shubham__9 baitho baitho....
# RT @sairatlicious: Sai ~ MERE PATI
# Virat ~ MERI PATNI
# Kaku ~ MAST HA MAST
# Karishma ~ DHADHO SUTTO
# Sonali ~ HO NA VAHINI
#
# Didi ~ bEizZaTi…
# @shyamsteel C. Chole Bhature
# @shyamsteel
#  #Virushka #Virat #Anushka #Contest #TVCContest #ContestAlert #ShyamSteel… https://t.co/OqBv63oNr1
# RT @wtfbunnyy: Me looking for Joe Root's Century in Australia https://t.co/SrmC5ccc9I
# RT @CricCrazyJohns: India ends as number 1 Test side in the annual ranking for the 5th consecutive year: 2017,2018,2019,2020,2021 - The dom…

# %%
pos= 0
neg = 0
neu = 0
for tweet in tweet_data :
  analysis = TextBlob(tweet.text)
  print(analysis.sentiment)
  if analysis.sentiment.polarity >0:
    print("POSITIVE")
    pos=pos+1
  elif analysis.sentiment.polarity == 0 :
      print("NEUTAL")
      neu=neu+1
  else:
        print("NEGATIVE")
        neg=neg+1
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.2, subjectivity=0.30000000000000004)
# POSITIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.5, subjectivity=1.0)
# POSITIVE
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)
# NEGATIVE
# Sentiment(polarity=0.5, subjectivity=0.5)
# POSITIVE
# Sentiment(polarity=0.0, subjectivity=1.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=-0.2, subjectivity=0.6)
# NEGATIVE
# Sentiment(polarity=0.5, subjectivity=1.0)
# POSITIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.175, subjectivity=0.44999999999999996)
# POSITIVE
# Sentiment(polarity=0.5, subjectivity=1.0)
# POSITIVE
# Sentiment(polarity=1.0, subjectivity=0.3)
# POSITIVE
# Sentiment(polarity=-0.15, subjectivity=0.39999999999999997)
# NEGATIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.5, subjectivity=0.5)
# POSITIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=1.0, subjectivity=0.3)
# POSITIVE
# Sentiment(polarity=0.30000000000000004, subjectivity=0.95)
# POSITIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=-0.15, subjectivity=0.39999999999999997)
# NEGATIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=1.0, subjectivity=0.3)
# POSITIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=1.0, subjectivity=0.3)
# POSITIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.5, subjectivity=0.5)
# POSITIVE
# Sentiment(polarity=0.5, subjectivity=1.0)
# POSITIVE
# Sentiment(polarity=1.0, subjectivity=0.3)
# POSITIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.1, subjectivity=0.35)
# POSITIVE
# Sentiment(polarity=1.0, subjectivity=0.3)
# POSITIVE
# Sentiment(polarity=0.375, subjectivity=0.6666666666666666)
# POSITIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.5, subjectivity=0.5)
# POSITIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=1.0, subjectivity=0.3)
# POSITIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=1.0, subjectivity=0.3)
# POSITIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.08333333333333333, subjectivity=0.19999999999999998)
# POSITIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=-0.15, subjectivity=0.39999999999999997)
# NEGATIVE
# Sentiment(polarity=0.5, subjectivity=0.5)
# POSITIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=-0.5, subjectivity=0.5)
# NEGATIVE
# Sentiment(polarity=-0.049999999999999996, subjectivity=0.26666666666666666)
# NEGATIVE
# Sentiment(polarity=0.0, subjectivity=0.03333333333333333)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=-0.049999999999999996, subjectivity=0.26666666666666666)
# NEGATIVE
# Sentiment(polarity=0.0, subjectivity=0.03333333333333333)
# NEUTAL
# Sentiment(polarity=-0.15, subjectivity=0.39999999999999997)
# NEGATIVE
# Sentiment(polarity=0.5, subjectivity=0.5)
# POSITIVE
# Sentiment(polarity=0.3, subjectivity=0.0)
# POSITIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=-0.15, subjectivity=0.39999999999999997)
# NEGATIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.5333333333333333, subjectivity=0.26666666666666666)
# POSITIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.5, subjectivity=1.0)
# POSITIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.43333333333333335, subjectivity=0.6333333333333333)
# POSITIVE
# Sentiment(polarity=0.2, subjectivity=0.6)
# POSITIVE
# Sentiment(polarity=-0.15, subjectivity=0.39999999999999997)
# NEGATIVE
# Sentiment(polarity=0.65, subjectivity=0.75)
# POSITIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=-0.5, subjectivity=1.0)
# NEGATIVE
# Sentiment(polarity=1.0, subjectivity=0.3)
# POSITIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=-0.5, subjectivity=0.5)
# NEGATIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL
# Sentiment(polarity=0.0, subjectivity=0.0)
# NEUTAL

# %%
   #TO PLOT THE GRAPH
plt.xlabel("tags")
plt.ylabel("polarity")
plt.bar(['pos','neg','neu'],[pos,neg,neu])
plt.pie([pos,neg,neu],labels = ['pos','neg','neu'], autopct= "%1.1f%%")
plt.show()
